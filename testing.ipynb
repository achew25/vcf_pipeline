# %%
from functions.parse_fasta import parse_fasta
import os
file_path = os.path.join("..", "data", "raw", "test_file.fasta")
parse_fasta(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 import os
#       3 file_path = os.path.join("..", "data", "raw", "test_file.fasta")
# ----> 4 parse_fasta(file_path)
#
# File c:\Users\anton\OneDrive - University of Bath\Documents\GitHub\rp1b\functions\parse_fasta.py:4, in parse_fasta(file_path)
#       2 import os
#       3 if not os.path.exists(file_path):
# ----> 4     raise FileNotFoundError(f"File not found: {file_path}")
#       5 with open(file_path, "r") as file:
#       6     lines = file.read().strip().split("\n")
#
# FileNotFoundError: File not found: ..\data\raw\test_file.fasta
